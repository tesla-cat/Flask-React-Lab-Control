# %%
import autograd.numpy as np
import scipy
from qutip import qeye, sigmax, sigmay, tensor, fock
from tested.getCtrl import getCtrl, pltCtrl
from tested.getFid import getFid
from tested.minimize import minimize, test

#test()

def outer(a,b): return a*b.dag()
def sigx(j,k): return  outer(k,j) + outer(j,k)
def sigy(j,k): return (outer(k,j) - outer(j,k)) * 1j
def H0j(j,N,delta,lam):
    ka = fock(N, j-1); kb = fock(N, j)
    return delta[j] * outer(kb,kb) 
def Hxj(j,N,delta,lam):
    ka = fock(N, j-1); kb = fock(N, j)
    return 1/2 * lam[j] * sigx(ka,kb)
def Hyj(j,N,delta,lam):
    ka = fock(N, j-1); kb = fock(N, j)
    return 1/2 * lam[j] * sigy(ka,kb)
def H0(N,delta,lam): return sum([H0j(j,N,delta,lam) for j in range(1,N)])
def Hx(N,delta,lam): return sum([Hxj(j,N,delta,lam) for j in range(1,N)])
def Hy(N,delta,lam): return sum([Hyj(j,N,delta,lam) for j in range(1,N)])

lam2 = np.sqrt(2)    # relative strength of the 0 − 1 to 1 − 2 transition
lam=[None, 1, lam2, lam2**2]

Delta= -2*np.pi * 0.4    # anharmonicity: −0.4 GHz 
del1 = 0
del2 = Delta + del1
del3 = Delta + del2
delta=[None, del1, del2, del3]

N=4   # dimension

a0 = np.random.rand(2, 10, 3)
T = np.pi
a0[:,:,1] /= T
pltCtrl(a0, T)
U0 = np.array(qeye(N).full())
Ugoal = np.array(tensor(sigmax(), qeye(N-2)).full())
H0 = np.array(H0(N,delta,lam))
Hcs = [np.array(Hx(N,delta,lam).full()), np.array(Hy(N,delta,lam).full())]
def Hat(a,t):
    c = getCtrl(a, t, T) + 1e-3
    return sum([ c[i]*Hcs[i] for i in range(len(Hcs)) ])
def goalFunc(U):
    fid = getFid(Ugoal, U)
    return 1 - fid
def callback(a):
    pltCtrl(a, T)
a = minimize(a0, U0, Hat, T, goalFunc, callback)
# Out:
# 9E-01 1E+00 1E+00 9E-01 9E-01 9E-01 8E-01 4E-01 4E-01 4E-01 4E-01
# Initial params: goal = 9E-01
#  [[[0.28849486 0.30996293 0.09961153]]
#
#  [[0.46860896 0.09985357 0.11222657]]]
# Final params: goal = 4E-01
#  [[[0.26229718 0.31019639 0.09959438]]
#
#  [[2.36029601 0.18272362 0.30250272]]]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-ce4a153b1c39> in <module>
#      51 def callback(a):
#      52     pltCtrl(a, T)
# ---> 53 a = minimize(a0, U0, Hat, T, goalFunc, callback)
#      54
#
# ~\Desktop\qoc\1 Implementations\AQUA\custom\tested\minimize.py in minimize(a0, U0, Hat, T, goalFunc, callback)
#      35             respond(x)
#      36         return goal, grad
# ---> 37     sol = scipy.optimize.minimize(fun=fun, x0=x0, method='L-BFGS-B', jac=True)
#      38     respond(sol.x)
#      39     def log(params, iter, gradient):
#
# c:\python38\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     607                                   **options)
#     608     elif meth == 'l-bfgs-b':
# --> 609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#
# c:\python38\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# c:\python38\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# c:\python38\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# c:\python38\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# ~\Desktop\qoc\1 Implementations\AQUA\custom\tested\minimize.py in fun(x)
#      34         except KeyboardInterrupt:
#      35             respond(x)
# ---> 36         return goal, grad
#      37     sol = scipy.optimize.minimize(fun=fun, x0=x0, method='L-BFGS-B', jac=True)
#      38     respond(sol.x)
#
# UnboundLocalError: local variable 'grad' referenced before assignment
