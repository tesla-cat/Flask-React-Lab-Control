# %%
from goat import goat
from qutip import qeye, sigmax, sigmay, fock, tensor
import jax.numpy as np
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
I = qeye(2); sx = sigmax(); sy = sigmay()

H0 = I*0; Hcs = [sx, sy]
T = np.pi/2; nT = 100
psi0 = I; psig = sx

p = goat(H0, Hcs, T, nT, psi0, psig, nC = 6)
# Out:
# 0.17989892 Traced<ConcreteArray(0.17989892)>with<JVPTrace(level=2/0)>
#   with primal = DeviceArray(0.17989892, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=1/0)>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-7ac7953c6bac> in <module>
#       5 psi0 = I; psig = sx
#       6
# ----> 7 p = goat(H0, Hcs, T, nT, psi0, psig, nC = 6)
#
# /mnt/c/Users/e0134117/Desktop/qoc/1 Implementations/6 GOAT autograd/goat.py in goat(H0, Hcs, T, nT, U0, Ug, nC)
#      77         pass
#      78     pltCtrl(saver.a, T, nT, 'optimized pulse infidelity = %.0e' % saver.goal, envf)
# ---> 79
#      80 def pltCtrl(a, T, nT, name, envf):
#      81     plt.title(name)
#
# AttributeError: 'Saver' object has no attribute 'a'

# %%
from Hqc import Hqc, cat

NQ = 2; NC = 15
v1 = tensor(fock(NQ, 0), fock(NC, 0))
v2 = tensor(fock(NQ, 0), cat(NC, 1.2))

H0, Hcs = Hqc(NQ, NC, drive=1e-3, chi=3e-3, kerrQ=0.4, kerrC=1e-5)
T = 200; nT = 200
psi0 = [v1]; psig = [v2]

p = goat(H0, Hcs, T, nT, psi0, psig, nC = 16)
