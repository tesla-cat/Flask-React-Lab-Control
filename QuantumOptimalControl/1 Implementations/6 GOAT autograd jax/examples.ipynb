# %%
from goat import goat
from qutip import qeye, sigmax, sigmay, fock, tensor
import jax.numpy as np
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
I = qeye(2); sx = sigmax(); sy = sigmay()

H0 = I*0; Hcs = [sx, sy]
T = np.pi/2; nT = 100
psi0 = I; psig = sx

p = goat(H0, Hcs, T, nT, psi0, psig, nC = 6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-7ac7953c6bac> in <module>
#       5 psi0 = I; psig = sx
#       6
# ----> 7 p = goat(H0, Hcs, T, nT, psi0, psig, nC = 6)
#
# /mnt/c/Users/e0134117/Desktop/qoc/1 Implementations/6 GOAT autograd jax/goat.py in goat(H0, Hcs, T, nT, U0, Ug, nC)
#      34     H0, Hcs, U0, Ug = toNp(H0, Hcs, U0, Ug)
#      35     a0 = np.ones([ len(Hcs), nC, 3 ])
# ---> 36     a0[:,:,1] = 1/T
#      37     #=====================================
#      38     mu = T/2
#
# ~/.local/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _unimplemented_setitem(self, i, x)
#    4829          "immutable; perhaps you want jax.ops.index_update or "
#    4830          "jax.ops.index_add instead?")
# -> 4831   raise TypeError(msg.format(type(self)))
#    4832
#    4833 def _operator_round(number, ndigits=None):
#
# TypeError: '<class 'jax.interpreters.xla.DeviceArray'>' object does not support item assignment. JAX arrays are immutable; perhaps you want jax.ops.index_update or jax.ops.index_add instead?

# %%
from Hqc import Hqc, cat

NQ = 2; NC = 15
v1 = tensor(fock(NQ, 0), fock(NC, 0))
v2 = tensor(fock(NQ, 0), cat(NC, 1.2))

H0, Hcs = Hqc(NQ, NC, drive=1e-3, chi=3e-3, kerrQ=0.4, kerrC=1e-5)
T = 200; nT = 200
psi0 = [v1]; psig = [v2]

p = goat(H0, Hcs, T, nT, psi0, psig, nC = 16)
# Out:
# 4e-01
